# %% [markdown]
# <a href="https://colab.research.google.com/github/UgriumovAndrei/pandas_dz1/blob/main/DZ_SEM3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data=pd.read_csv('/content/kc_house_data_NaN.csv',sep=',')
data.head()
# Out:
#    Unnamed: 0          id             date     price  bedrooms  bathrooms  \
# 0           0  7129300520  20141013T000000  221900.0       3.0       1.00
# 1           1  6414100192  20141209T000000  538000.0       3.0       2.25
# 2           2  5631500400  20150225T000000  180000.0       2.0       1.00
# 3           3  2487200875  20141209T000000  604000.0       4.0       3.00
# 4           4  1954400510  20150218T000000  510000.0       3.0       2.00
#
#    sqft_living  sqft_lot  floors  waterfront  ...  grade  sqft_above  \
# 0         1180      5650     1.0           0  ...      7        1180
# 1         2570      7242     2.0           0  ...      7        2170
# 2          770     10000     1.0           0  ...      6         770
# 3         1960      5000     1.0           0  ...      7        1050
# 4         1680      8080     1.0           0  ...      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
data.shape
# Out:
# (21613, 22)

# %% [markdown]
# 1.2 Создать новый признак delta_renovated, который будет содержать разницу в годах между годом реновацией дома и годом постройки дома
# Если реновации дома не было, то в новом признаке поставьте 0
# 1.3 Создайте признаки года продажи, месяца продажи
# 1.4 Удалите признаки date, zipcode, lat, long
#
# Условие 2: 2 задача
# Создайте датафрейм с клиентами:
# clients = pd.DataFrame({
# 'client_id': [1459, 4684, 3498, 3942, 4535, 2308, 2866, 2765, 1472, 4236, 2295,
# 939, 3840, 280, 20, 4332, 3475, 4213, 3113, 4809, 2134, 2242,
# 2068, 4929, 1384, 1589, 3317, 2260, 1727, 1764, 1611, 1474],
# 'house_id': [8965450190, 6823100225, 5104540330, 2131701075, 1522700060,
# 1189000207, 6821600300, 7137950720, 9510920050, 6131600255,
# 5428000070, 1788800910, 8100400160, 3123049142, 6306800010,
# 5083000375, 7920100025, 1951600150, 809001400, 339600110,
# 1622049154, 1099600250, 8563000110, 2768100205, 3995700435,
# 8861700030, 3303980210, 7731100066, 8146100580, 825069097,
# 3889100029, 9524100196]
# })
# 2.1 Присоедините к таблице clients данные по домам через метод join
# 2.2 Присоедините к таблице clients данные по домам через метод merge
# Это нужно, чтобы понимать, какие дома покупались клиентами
# house_id - это индексы датафрейма с домами
# Условие 3: 3 задача
# Составьте несколько сводных таблиц
# 3.1 Найдите среднюю стоимость домов в зависимости от количества спален
# Отсортируйте от меньшей стоимости к большей
# 3.2 Найдите минимальную, среднюю и максимальную стоимости домов в зависимости от состояния дома
# 3.3 Постройте таблицу с подсчетом количества домов в данных в зависимости от вида на набережную и оценкой вида
# 3.4 Каких домов в зависимости от этажности и количества спален больше?
# 3.5 Постройте таблицу с подсчетом медианной стоимости домов в данных в зависимости от состояния дома и оценки дома

# %%
def renovated(r,postr):
  if r==0:
    return 0
  else:
    return r-postr
renovated(0,1905)
# Out:
# 0

# %%
data['target']=0
#data['delta_renovated'].head()

# %%
data.loc[(data['yr_renovated']>0),'target']=data['yr_renovated']- data['yr_built']
data['delta_renovated']=data['target']
#data.drop(columns=['target'],inplace=True)
#data.loc[(data['delta_renovated']==0)].count()

# %%
data.drop(columns=['zipcode','lat','long'],inplace=True)
data.head()
# Out:
#    Unnamed: 0          id             date     price  bedrooms  bathrooms  \
# 0           0  7129300520  20141013T000000  221900.0       3.0       1.00
# 1           1  6414100192  20141209T000000  538000.0       3.0       2.25
# 2           2  5631500400  20150225T000000  180000.0       2.0       1.00
# 3           3  2487200875  20141209T000000  604000.0       4.0       3.00
# 4           4  1954400510  20150218T000000  510000.0       3.0       2.00
#
#    sqft_living  sqft_lot  floors  waterfront  ...  condition  grade  \
# 0         1180      5650     1.0           0  ...          3      7
# 1         2570      7242     2.0           0  ...          3      7
# 2          770     10000     1.0           0  ...          3      6
# 3         1960      5000     1.0           0  ...          5      7
# 4         1680      8080     1.0           0  ...          3      8
#
#    sqft_above  sqft_basement  yr_built  yr_renovated  sqft_living15  \
# ...

# %%
data.drop(columns=['target'],inplace=True)

# %%
def month(x):
  return x[4:6]

# %%
month('20141013T000000')
# Out:
# '10'

# %%
def year(x):
  return x[:4]

# %%
data['month']=data['date'].apply(month)
data['year']=data['date'].apply(year)

# %%
data.drop(columns=['date'],inplace=True)
data.head()
# Out:
#    Unnamed: 0          id     price  bedrooms  bathrooms  sqft_living  \
# 0           0  7129300520  221900.0       3.0       1.00         1180
# 1           1  6414100192  538000.0       3.0       2.25         2570
# 2           2  5631500400  180000.0       2.0       1.00          770
# 3           3  2487200875  604000.0       4.0       3.00         1960
# 4           4  1954400510  510000.0       3.0       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  sqft_living15  sqft_lot15  delta_renovated  month  \
# ...

# %%
clients = pd.DataFrame({ 'client_id': [1459, 4684, 3498, 3942, 4535, 2308, 2866, 2765, 1472, 4236, 2295, 939, 3840, 280, 20, 4332, 3475, 4213, 3113, 4809, 2134, 2242, 2068, 4929, 1384, 1589, 3317, 2260, 1727, 1764, 1611, 1474], 'house_id': [8965450190, 6823100225, 5104540330, 2131701075, 1522700060, 1189000207, 6821600300, 7137950720, 9510920050, 6131600255, 5428000070, 1788800910, 8100400160, 3123049142, 6306800010, 5083000375, 7920100025, 1951600150, 809001400, 339600110, 1622049154, 1099600250, 8563000110, 2768100205, 3995700435, 8861700030, 3303980210, 7731100066, 8146100580, 825069097, 3889100029, 9524100196] })

# %%
merged_data=data.merge(clients, left_on='id',right_on='house_id', how='left')

# %%
merged_data.head()
# Out:
#    Unnamed: 0          id     price  bedrooms  bathrooms  sqft_living  \
# 0           0  7129300520  221900.0       3.0       1.00         1180
# 1           1  6414100192  538000.0       3.0       2.25         2570
# 2           2  5631500400  180000.0       2.0       1.00          770
# 3           3  2487200875  604000.0       4.0       3.00         1960
# 4           4  1954400510  510000.0       3.0       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_basement  yr_built  \
# 0      5650     1.0           0     0  ...              0      1955
# 1      7242     2.0           0     0  ...            400      1951
# 2     10000     1.0           0     0  ...              0      1933
# 3      5000     1.0           0     0  ...            910      1965
# 4      8080     1.0           0     0  ...              0      1987
#
#    yr_renovated  sqft_living15  sqft_lot15  delta_renovated  month  year  \
# ...

# %%
data.pivot_table(#index='id',
                  values='price',
                  columns=['bedrooms'],
                  aggfunc=['mean'])
# Out:
#                    mean                                               \
# bedrooms           1.0            2.0            3.0            4.0
# price     317642.884422  401372.681884  466232.078481  635419.504214
#
#                                                                      \
# bedrooms           5.0            6.0            7.0           8.0
# price     786599.828857  825520.636029  951184.657895  1.105077e+06
#
#
# bedrooms           9.0            10.0      11.0      33.0
# price     893999.833333  819333.333333  520000.0  640000.0

# %%
data.describe()
# Out:
#         Unnamed: 0            id         price      bedrooms     bathrooms  \
# count  21613.00000  2.161300e+04  2.161300e+04  21600.000000  21603.000000
# mean   10806.00000  4.580302e+09  5.400881e+05      3.372870      2.115736
# std     6239.28002  2.876566e+09  3.671272e+05      0.926657      0.768996
# min        0.00000  1.000102e+06  7.500000e+04      1.000000      0.500000
# 25%     5403.00000  2.123049e+09  3.219500e+05      3.000000      1.750000
# 50%    10806.00000  3.904930e+09  4.500000e+05      3.000000      2.250000
# 75%    16209.00000  7.308900e+09  6.450000e+05      4.000000      2.500000
# max    21612.00000  9.900000e+09  7.700000e+06     33.000000      8.000000
#
#         sqft_living      sqft_lot        floors    waterfront          view  \
# count  21613.000000  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean    2079.899736  1.510697e+04      1.494309      0.007542      0.234303
# ...

# %%
data.pivot_table(#index='id',
                  values='price',
                  columns=['condition'],
                  aggfunc=['mean','min','max'])
# Out:
#                     mean                                               \
# condition              1              2              3              4
# price      334431.666667  327287.145349  542012.578148  521200.390033
#
#                               min                                       \
# condition              5        1        2        3        4         5
# price      612418.089359  78000.0  80000.0  75000.0  89000.0  110000.0
#
#                  max
# condition          1          2          3          4          5
# price      1500000.0  2555000.0  7062500.0  7700000.0  3650000.0

# %%
Постройте таблицу с подсчетом количества домов в данных в зависимости от вида на набережную и оценкой вида 3.4 Каких домов в зависимости от этажности и количества спален больше? 3.5 Постройте таблицу с подсчетом медианной стоимости домов в данных в зависимости от состояния дома и оценки дома
# Out:
#   File "<ipython-input-22-9130f5d913f3>", line 1
#     Постройте таблицу с подсчетом количества домов в данных в зависимости от вида на набережную и оценкой вида 3.4 Каких домов в зависимости от этажности и количества спален больше? 3.5 Постройте таблицу с подсчетом медианной стоимости домов в данных в зависимости от состояния дома и оценки дома
#               ^
# SyntaxError: invalid syntax

# %%
data.pivot_table(#index='id',
                  values='id',
                  columns=['waterfront','view'])
# Out:
# waterfront             0                                            \
# view                   0             1             2             3
# id          4.569471e+09  4.624063e+09  4.766280e+09  4.390288e+09
#
# waterfront                           1                              \
# view                   4             1             2             3
# id          5.270002e+09  2.623029e+09  5.740514e+09  3.208181e+09
#
# waterfront
# view                   4
# id          4.610747e+09

# %%
grouped=data.groupby(['waterfront','view']).count()
grouped
# Out:
#                  Unnamed: 0     id  price  bedrooms  bathrooms  sqft_living  \
# waterfront view
# 0          0          19489  19489  19489     19478      19481        19489
#            1            331    331    331       331        331          331
#            2            955    955    955       953        953          955
#            3            491    491    491       491        491          491
#            4            184    184    184       184        184          184
# 1          1              1      1      1         1          1            1
#            2              8      8      8         8          8            8
#            3             19     19     19        19         19           19
#            4            135    135    135       135        135          135
#
#                  sqft_lot  floors  condition  grade  sqft_above  \
# waterfront view
# 0          0        19489   19489      19489  19489       19489
# ...

# %%
grouped=data.groupby(['floors','bedrooms']).count() 
grouped
# Out:
#                  Unnamed: 0    id  price  bathrooms  sqft_living  sqft_lot  \
# floors bedrooms
# 1.0    1.0              162   162    162        159          162       162
#        2.0             1951  1951   1951       1951         1951      1951
#        3.0             5455  5455   5455       5455         5455      5455
#        4.0             2383  2383   2383       2383         2383      2383
#        5.0              605   605    605        605          605       605
#        6.0              104   104    104        104          104       104
#        7.0                9     9      9          9            9         9
#        8.0                5     5      5          5            5         5
#        10.0               1     1      1          1            1         1
#        33.0               1     1      1          1            1         1
# 1.5    1.0               21    21     21         21           21        21
# ...

# %%
data.pivot_table(#index='id',
                  values='price',
                  columns=['condition','grade'],
                  aggfunc='median')
# Out:
# condition         1                                                    \
# grade            1         4         5         6         7         8
# price      142000.0  150000.0  190000.0  255000.0  403500.0  932500.0
#
# condition         2                                ...          4         5  \
# grade            3         4         5         6   ...         13        3
# price      280000.0  145000.0  180000.0  235000.0  ...  5750000.0  262000.0
#
# condition                                                                \
# grade            5         6         7         8          9          10
# price      227450.0  285475.0  456000.0  696000.0  1078000.0  1650000.0
#
# condition
# grade             11         12
# price      2050000.0  1990000.0
#
# [1 rows x 44 columns]
