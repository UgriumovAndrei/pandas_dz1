# %% [markdown]
# <a href="https://colab.research.google.com/github/UgriumovAndrei/pandas_dz1/blob/main/PandasLekt4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('bank.csv',sep=',')
df.sample(n=10)
# Out:
#        age            job   marital  education default  balance housing loan  \
# 1867    38  self-employed    single   tertiary      no     1612     yes   no
# 6787    40  self-employed   married  secondary      no     1516     yes  yes
# 661     60     management  divorced  secondary      no        0      no   no
# 166     56    blue-collar   married  secondary      no      249     yes   no
# 5058    32    blue-collar   married  secondary      no      225     yes   no
# 4583    25        student    single  secondary      no      125      no   no
# 2798    19        student    single  secondary      no      329      no   no
# 1849    39     technician  divorced  secondary      no      291     yes   no
# 10637   33     technician   married  secondary      no      218     yes  yes
# 7048    38    blue-collar    single  secondary      no    13156     yes   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
data= df.groupby('month')['job'].agg(count='count').reset_index().sort_values(by='month')
data.head(10)
# Out:
#   month  count
# 0   apr    923
# 1   aug   1519
# 2   dec    110
# 3   feb    776
# 4   jan    344
# 5   jul   1514
# 6   jun   1222
# 7   mar    276
# 8   may   2824
# 9   nov    943

# %%
plt.figure(figsize=(8,6))
plt.plot(data['month'],data['count'])
plt.xlabel('Месяц')
plt.ylabel('Кол-во клиентов')
plt.title('Охват клиентов по месяцам')
# Out:
# Text(0.5, 1.0, 'Охват клиентов по месяцам')

# %%
plt.figure(figsize=(8,6))
plt.hist(df['age'], bins=100);

# %%
plt.figure(figsize=(8,6))
sns.histplot(df['age'], bins=100)
plt.xlabel('Возраст');

# %%
data=df['job'].value_counts().reset_index()
data.head(15)
# Out:
#             index   job
# 0      management  2566
# 1     blue-collar  1944
# 2      technician  1823
# 3          admin.  1334
# 4        services   923
# 5         retired   778
# 6   self-employed   405
# 7         student   360
# 8      unemployed   357
# 9    entrepreneur   328
# 10      housemaid   274
# 11        unknown    70

# %%
plt.figure(figsize=(15,6))
plt.bar(data['index'],data['job']);
